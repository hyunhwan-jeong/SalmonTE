# %%
from bs4 import BeautifulSoup

# %%
html = """<select><option value="All">All</option>

<option value="Transposable Element">Transposable Element</option>
<option value="DNA transposon">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;DNA transposon</option>
<option value="Mariner/Tc1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Mariner/Tc1</option>
<option value="hAT">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;hAT</option>
<option value="MuDR">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;MuDR</option>
<option value="EnSpm/CACTA">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;EnSpm/CACTA</option>
<option value="piggyBac">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;piggyBac</option>
<option value="P">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;P</option>
<option value="Merlin">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Merlin</option>
<option value="Harbinger">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Harbinger</option>
<option value="Transib">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Transib</option>
<option value="Novosib">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Novosib</option>
<option value="Helitron">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Helitron</option>
<option value="Polinton">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Polinton</option>
<option value="Kolobok">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Kolobok</option>
<option value="ISL2EU">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ISL2EU</option>
<option value="Crypton">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Crypton</option>
<option value="CryptonA">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CryptonA</option>
<option value="CryptonF">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CryptonF</option>
<option value="CryptonI">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CryptonI</option>
<option value="CryptonS">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CryptonS</option>
<option value="CryptonV">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CryptonV</option>
<option value="Sola">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sola</option>
<option value="Sola1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sola1</option>
<option value="Sola2">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sola2</option>
<option value="Sola3">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sola3</option>
<option value="Zator">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Zator</option>
<option value="Ginger1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ginger1</option>
<option value="Ginger2/TDD">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ginger2/TDD</option>
<option value="Academ">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Academ</option>
<option value="Zisupton">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Zisupton</option>
<option value="IS3EU">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;IS3EU</option>
<option value="Dada">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Dada</option>
<option value="LTR Retrotransposon">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;LTR Retrotransposon</option>
<option value="Gypsy">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Gypsy</option>
<option value="Copia">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Copia</option>
<option value="BEL">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;BEL</option>
<option value="DIRS">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;DIRS</option>
<option value="Endogenous Retrovirus">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Endogenous Retrovirus</option>
<option value="ERV1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ERV1</option>
<option value="ERV2">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ERV2</option>
<option value="ERV3">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ERV3</option>
<option value="Lentivirus">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lentivirus</option>
<option value="ERV4">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ERV4</option>
<option value="Non-LTR Retrotransposon">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Non-LTR Retrotransposon</option>
<option value="SINE">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;SINE</option>
<option value="SINE1/7SL">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;SINE1/7SL</option>
<option value="SINE2/tRNA">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;SINE2/tRNA</option>
<option value="SINE3/5S">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;SINE3/5S</option>
<option value="SINE4">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;SINE4</option>
<option value="SINEU/snRNA">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;SINEU/snRNA</option>
<option value="CRE">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CRE</option>
<option value="NeSL">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;NeSL</option>
<option value="R4">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;R4</option>
<option value="R2">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;R2</option>
<option value="L1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;L1</option>
<option value="RTE">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;RTE</option>
<option value="I">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;I</option>
<option value="Jockey">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Jockey</option>
<option value="CR1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CR1</option>
<option value="Rex1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Rex1</option>
<option value="RandI">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;RandI</option>
<option value="Penelope">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Penelope</option>
<option value="Tx1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Tx1</option>
<option value="RTEX">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;RTEX</option>
<option value="Crack">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Crack</option>
<option value="Nimb">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Nimb</option>
<option value="Proto1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Proto1</option>
<option value="Proto2">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Proto2</option>
<option value="RTETP">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;RTETP</option>
<option value="Hero">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hero</option>
<option value="L2">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;L2</option>
<option value="Tad1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Tad1</option>
<option value="Loa">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Loa</option>
<option value="Ingi">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ingi</option>
<option value="Outcast">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Outcast</option>
<option value="R1">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;R1</option>
<option value="Daphne">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Daphne</option>
<option value="L2A">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;L2A</option>
<option value="L2B">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;L2B</option>
<option value="Ambal">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ambal</option>
<option value="Vingi">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Vingi</option>
<option value="Kiri">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Kiri</option>
<option value="Simple Repeat">Simple Repeat</option>
<option value="Satellite">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Satellite</option>
<option value="SAT">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;SAT</option>
<option value="MSAT">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;MSAT</option>
<option value="Multicopy gene">Multicopy gene</option>
<option value="rRNA">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;rRNA</option>
<option value="tRNA">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;tRNA</option>
<option value="snRNA">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;snRNA</option>
<option value="Integrated Virus">Integrated Virus</option>
<option value="DNA Virus">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;DNA Virus</option>
<option value="Caulimoviridae">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Caulimoviridae</option></select>"""

# %%
bs = BeautifulSoup(html, "html5lib")

# %%
with open("clades.tsv", "r") as inp:
    print(inp.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-3b6d8637c35f> in <module>()
# ----> 1 with open("clades.tsv", "r") as inp:
#       2     print(inp.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'clades.tsv'

# %%
with open("clades_extended.csv", "w") as oup:
    repeat_class = None
    sub_class = None
    print("name", "repeat_class", "clade", sep=",", file=oup)
    for opt in bs.findAll("option")[1:]:
        if len(opt.text.strip())+6 == len(opt.text):
            print(opt)
            sub_class = opt.text.strip()
            continue
        elif opt.text == opt.text.strip():
            print(opt)
            repeat_class = opt.text.strip()
            continue
        else:
            print(opt.text.strip(), repeat_class, sub_class, sep=",", file=oup)
# Out:
# <option value="Transposable Element">Transposable Element</option>
# <option value="DNA transposon">      DNA transposon</option>
# <option value="LTR Retrotransposon">      LTR Retrotransposon</option>
# <option value="Endogenous Retrovirus">      Endogenous Retrovirus</option>
# <option value="Non-LTR Retrotransposon">      Non-LTR Retrotransposon</option>
# <option value="Simple Repeat">Simple Repeat</option>
# <option value="Satellite">      Satellite</option>
# <option value="Multicopy gene">Multicopy gene</option>
# <option value="rRNA">      rRNA</option>
# <option value="tRNA">      tRNA</option>
# <option value="snRNA">      snRNA</option>
# <option value="Integrated Virus">Integrated Virus</option>
# <option value="DNA Virus">      DNA Virus</option>
# <option value="Caulimoviridae">      Caulimoviridae</option>

# %%
html = """<ul><small>
<li>Transposable Element
<ul>
<li>DNA transposon
<ul>
<li>Mariner/Tc1
</li><li>hAT
</li><li>MuDR
</li><li>EnSpm/CACTA
</li><li>piggyBac
</li><li>P
</li><li>Merlin
</li><li>Harbinger
</li><li>Transib
</li><li>Novosib
</li><li>Helitron
</li><li>Polinton
</li><li>Kolobok
</li><li>ISL2EU
</li><li>Crypton
<ul>
<li>CryptonA
</li><li>CryptonF
</li><li>CryptonI
</li><li>CryptonS
</li><li>CryptonV
</li></ul>
</li><li>Sola
<ul>
<li>Sola1
</li><li>Sola2
</li><li>Sola3
</li></ul>
</li><li>Zator
</li><li>Ginger1
</li><li>Ginger2/TDD
</li><li>Academ
</li><li>Zisupton
</li><li>IS3EU
</li><li>Dada
</li></ul>
</li><li>LTR Retrotransposon
<ul>
<li>Gypsy
</li><li>Copia
</li><li>BEL
</li><li>DIRS
</li></ul>
</li><li>Endogenous Retrovirus
<ul>
<li>ERV1
</li><li>ERV2
</li><li>ERV3
</li><li>Lentivirus
</li><li>ERV4
</li></ul>
</li><li>Non-LTR Retrotransposon
<ul>
<li>SINE
<ul>
<li>SINE1/7SL
</li><li>SINE2/tRNA
</li><li>SINE3/5S
</li><li>SINE4
</li><li>SINEU/snRNA
</li></ul>
</li><li>CRE
</li><li>NeSL
</li><li>R4
</li><li>R2
</li><li>L1
</li><li>RTE
</li><li>I
</li><li>Jockey
</li><li>CR1
</li><li>Rex1
</li><li>RandI
</li><li>Penelope
</li><li>Tx1
</li><li>RTEX
</li><li>Crack
</li><li>Nimb
</li><li>Proto1
</li><li>Proto2
</li><li>RTETP
</li><li>Hero
</li><li>L2
</li><li>Tad1
</li><li>Loa
</li><li>Ingi
</li><li>Outcast
</li><li>R1
</li><li>Daphne
</li><li>L2A
</li><li>L2B
</li><li>Ambal
</li><li>Vingi
</li><li>Kiri
</li></ul>
</li></ul>
</li><li>Simple Repeat
<ul>
<li>Satellite
<ul>
<li>SAT
</li><li>MSAT
</li></ul>
</li></ul>
</li><li>Multicopy gene
<ul>
<li>rRNA
</li><li>tRNA
</li><li>snRNA
</li></ul>
</li><li>Integrated Virus
<ul>
<li>DNA Virus
</li><li>Caulimoviridae
</li></ul>
</li></small></ul>"""

# %%
soup = BeautifulSoup(html, "html5lib")

# %%
ret = soup.findAll('ul', limit=1)

# %%
def recursiveChildren(x, stk):
    if "childGenerator" in dir(x):
        for child in x.childGenerator():
            name = getattr(child, "name", None)
            txt = ''
            if name is not None:
                txt = child.text.split('\n')[0]
                print("[Container Node]",child.name, txt)
            recursiveChildren(child, stk + [txt]) if len(txt)>0 else recursiveChildren(child, stk)
    else:
        print(stk)

# %%
recursiveChildren(soup.ul.small, [])
# Out:
# []
# [Container Node] li Transposable Element
# <li>Transposable Element
# <ul>
# <li>DNA transposon
# <ul>
# <li>Mariner/Tc1
# </li><li>hAT
# </li><li>MuDR
# </li><li>EnSpm/CACTA
# </li><li>piggyBac
# </li><li>P
# </li><li>Merlin
# </li><li>Harbinger
# </li><li>Transib
# </li><li>Novosib
# </li><li>Helitron
# </li><li>Polinton
# </li><li>Kolobok
# </li><li>ISL2EU
# </li><li>Crypton
# <ul>
# <li>CryptonA
# </li><li>CryptonF
# </li><li>CryptonI
# </li><li>CryptonS
# </li><li>CryptonV
# </li></ul>
# </li><li>Sola
# <ul>
# <li>Sola1
# </li><li>Sola2
# </li><li>Sola3
# </li></ul>
# </li><li>Zator
# </li><li>Ginger1
# </li><li>Ginger2/TDD
# </li><li>Academ
# </li><li>Zisupton
# </li><li>IS3EU
# </li><li>Dada
# </li></ul>
# </li><li>LTR Retrotransposon
# <ul>
# <li>Gypsy
# </li><li>Copia
# </li><li>BEL
# </li><li>DIRS
# </li></ul>
# </li><li>Endogenous Retrovirus
# <ul>
# <li>ERV1
# </li><li>ERV2
# </li><li>ERV3
# </li><li>Lentivirus
# </li><li>ERV4
# </li></ul>
# </li><li>Non-LTR Retrotransposon
# <ul>
# <li>SINE
# <ul>
# <li>SINE1/7SL
# </li><li>SINE2/tRNA
# </li><li>SINE3/5S
# </li><li>SINE4
# </li><li>SINEU/snRNA
# </li></ul>
# </li><li>CRE
# </li><li>NeSL
# </li><li>R4
# </li><li>R2
# </li><li>L1
# </li><li>RTE
# </li><li>I
# </li><li>Jockey
# </li><li>CR1
# </li><li>Rex1
# </li><li>RandI
# </li><li>Penelope
# </li><li>Tx1
# </li><li>RTEX
# </li><li>Crack
# </li><li>Nimb
# </li><li>Proto1
# </li><li>Proto2
# </li><li>RTETP
# </li><li>Hero
# </li><li>L2
# </li><li>Tad1
# </li><li>Loa
# </li><li>Ingi
# </li><li>Outcast
# </li><li>R1
# </li><li>Daphne
# </li><li>L2A
# </li><li>L2B
# </li><li>Ambal
# </li><li>Vingi
# </li><li>Kiri
# </li></ul>
# </li></ul>
# </li>
# Transposable Element
#
# ['Transposable Element']
# [Container Node] ul
# <ul>
# <li>DNA transposon
# <ul>
# <li>Mariner/Tc1
# </li><li>hAT
# </li><li>MuDR
# </li><li>EnSpm/CACTA
# </li><li>piggyBac
# </li><li>P
# </li><li>Merlin
# </li><li>Harbinger
# </li><li>Transib
# </li><li>Novosib
# </li><li>Helitron
# </li><li>Polinton
# </li><li>Kolobok
# </li><li>ISL2EU
# </li><li>Crypton
# <ul>
# <li>CryptonA
# </li><li>CryptonF
# </li><li>CryptonI
# </li><li>CryptonS
# </li><li>CryptonV
# </li></ul>
# </li><li>Sola
# <ul>
# <li>Sola1
# </li><li>Sola2
# </li><li>Sola3
# </li></ul>
# </li><li>Zator
# </li><li>Ginger1
# </li><li>Ginger2/TDD
# </li><li>Academ
# </li><li>Zisupton
# </li><li>IS3EU
# </li><li>Dada
# </li></ul>
# </li><li>LTR Retrotransposon
# <ul>
# <li>Gypsy
# </li><li>Copia
# </li><li>BEL
# </li><li>DIRS
# </li></ul>
# </li><li>Endogenous Retrovirus
# <ul>
# <li>ERV1
# </li><li>ERV2
# </li><li>ERV3
# </li><li>Lentivirus
# </li><li>ERV4
# </li></ul>
# </li><li>Non-LTR Retrotransposon
# <ul>
# <li>SINE
# <ul>
# <li>SINE1/7SL
# </li><li>SINE2/tRNA
# </li><li>SINE3/5S
# </li><li>SINE4
# </li><li>SINEU/snRNA
# </li></ul>
# </li><li>CRE
# </li><li>NeSL
# </li><li>R4
# </li><li>R2
# </li><li>L1
# </li><li>RTE
# </li><li>I
# </li><li>Jockey
# </li><li>CR1
# </li><li>Rex1
# </li><li>RandI
# </li><li>Penelope
# </li><li>Tx1
# </li><li>RTEX
# </li><li>Crack
# </li><li>Nimb
# </li><li>Proto1
# </li><li>Proto2
# </li><li>RTETP
# </li><li>Hero
# </li><li>L2
# </li><li>Tad1
# </li><li>Loa
# </li><li>Ingi
# </li><li>Outcast
# </li><li>R1
# </li><li>Daphne
# </li><li>L2A
# </li><li>L2B
# </li><li>Ambal
# </li><li>Vingi
# </li><li>Kiri
# </li></ul>
# </li></ul>
#
#
# ['Transposable Element']
# [Container Node] li DNA transposon
# <li>DNA transposon
# <ul>
# <li>Mariner/Tc1
# </li><li>hAT
# </li><li>MuDR
# </li><li>EnSpm/CACTA
# </li><li>piggyBac
# </li><li>P
# </li><li>Merlin
# </li><li>Harbinger
# </li><li>Transib
# </li><li>Novosib
# </li><li>Helitron
# </li><li>Polinton
# </li><li>Kolobok
# </li><li>ISL2EU
# </li><li>Crypton
# <ul>
# <li>CryptonA
# </li><li>CryptonF
# </li><li>CryptonI
# </li><li>CryptonS
# </li><li>CryptonV
# </li></ul>
# </li><li>Sola
# <ul>
# <li>Sola1
# </li><li>Sola2
# </li><li>Sola3
# </li></ul>
# </li><li>Zator
# </li><li>Ginger1
# </li><li>Ginger2/TDD
# </li><li>Academ
# </li><li>Zisupton
# </li><li>IS3EU
# </li><li>Dada
# </li></ul>
# </li>
# DNA transposon
#
# ['Transposable Element', 'DNA transposon']
# [Container Node] ul
# <ul>
# <li>Mariner/Tc1
# </li><li>hAT
# </li><li>MuDR
# </li><li>EnSpm/CACTA
# </li><li>piggyBac
# </li><li>P
# </li><li>Merlin
# </li><li>Harbinger
# </li><li>Transib
# </li><li>Novosib
# </li><li>Helitron
# </li><li>Polinton
# </li><li>Kolobok
# </li><li>ISL2EU
# </li><li>Crypton
# <ul>
# <li>CryptonA
# </li><li>CryptonF
# </li><li>CryptonI
# </li><li>CryptonS
# </li><li>CryptonV
# </li></ul>
# </li><li>Sola
# <ul>
# <li>Sola1
# </li><li>Sola2
# </li><li>Sola3
# </li></ul>
# </li><li>Zator
# </li><li>Ginger1
# </li><li>Ginger2/TDD
# </li><li>Academ
# </li><li>Zisupton
# </li><li>IS3EU
# </li><li>Dada
# </li></ul>
#
#
# ['Transposable Element', 'DNA transposon']
# [Container Node] li Mariner/Tc1
# <li>Mariner/Tc1
# </li>
# Mariner/Tc1
#
# ['Transposable Element', 'DNA transposon', 'Mariner/Tc1']
# [Container Node] li hAT
# <li>hAT
# </li>
# hAT
#
# ['Transposable Element', 'DNA transposon', 'hAT']
# [Container Node] li MuDR
# <li>MuDR
# </li>
# MuDR
#
# ['Transposable Element', 'DNA transposon', 'MuDR']
# [Container Node] li EnSpm/CACTA
# <li>EnSpm/CACTA
# </li>
# EnSpm/CACTA
#
# ['Transposable Element', 'DNA transposon', 'EnSpm/CACTA']
# [Container Node] li piggyBac
# <li>piggyBac
# </li>
# piggyBac
#
# ['Transposable Element', 'DNA transposon', 'piggyBac']
# [Container Node] li P
# <li>P
# </li>
# P
#
# ['Transposable Element', 'DNA transposon', 'P']
# [Container Node] li Merlin
# <li>Merlin
# </li>
# Merlin
#
# ['Transposable Element', 'DNA transposon', 'Merlin']
# [Container Node] li Harbinger
# <li>Harbinger
# </li>
# Harbinger
#
# ['Transposable Element', 'DNA transposon', 'Harbinger']
# [Container Node] li Transib
# <li>Transib
# </li>
# Transib
#
# ['Transposable Element', 'DNA transposon', 'Transib']
# [Container Node] li Novosib
# <li>Novosib
# </li>
# Novosib
#
# ['Transposable Element', 'DNA transposon', 'Novosib']
# [Container Node] li Helitron
# <li>Helitron
# </li>
# Helitron
#
# ['Transposable Element', 'DNA transposon', 'Helitron']
# [Container Node] li Polinton
# <li>Polinton
# </li>
# Polinton
#
# ['Transposable Element', 'DNA transposon', 'Polinton']
# [Container Node] li Kolobok
# <li>Kolobok
# </li>
# Kolobok
#
# ['Transposable Element', 'DNA transposon', 'Kolobok']
# [Container Node] li ISL2EU
# <li>ISL2EU
# </li>
# ISL2EU
#
# ['Transposable Element', 'DNA transposon', 'ISL2EU']
# [Container Node] li Crypton
# <li>Crypton
# <ul>
# <li>CryptonA
# </li><li>CryptonF
# </li><li>CryptonI
# </li><li>CryptonS
# </li><li>CryptonV
# </li></ul>
# </li>
# Crypton
#
# ['Transposable Element', 'DNA transposon', 'Crypton']
# [Container Node] ul
# <ul>
# <li>CryptonA
# </li><li>CryptonF
# </li><li>CryptonI
# </li><li>CryptonS
# </li><li>CryptonV
# </li></ul>
#
#
# ['Transposable Element', 'DNA transposon', 'Crypton']
# [Container Node] li CryptonA
# <li>CryptonA
# </li>
# CryptonA
#
# ['Transposable Element', 'DNA transposon', 'Crypton', 'CryptonA']
# [Container Node] li CryptonF
# <li>CryptonF
# </li>
# CryptonF
#
# ['Transposable Element', 'DNA transposon', 'Crypton', 'CryptonF']
# [Container Node] li CryptonI
# <li>CryptonI
# </li>
# CryptonI
#
# ['Transposable Element', 'DNA transposon', 'Crypton', 'CryptonI']
# [Container Node] li CryptonS
# <li>CryptonS
# </li>
# CryptonS
#
# ['Transposable Element', 'DNA transposon', 'Crypton', 'CryptonS']
# [Container Node] li CryptonV
# <li>CryptonV
# </li>
# CryptonV
#
# ['Transposable Element', 'DNA transposon', 'Crypton', 'CryptonV']
#
#
# ['Transposable Element', 'DNA transposon', 'Crypton']
# [Container Node] li Sola
# <li>Sola
# <ul>
# <li>Sola1
# </li><li>Sola2
# </li><li>Sola3
# </li></ul>
# </li>
# Sola
#
# ['Transposable Element', 'DNA transposon', 'Sola']
# [Container Node] ul
# <ul>
# <li>Sola1
# </li><li>Sola2
# </li><li>Sola3
# </li></ul>
#
#
# ['Transposable Element', 'DNA transposon', 'Sola']
# [Container Node] li Sola1
# <li>Sola1
# </li>
# Sola1
#
# ['Transposable Element', 'DNA transposon', 'Sola', 'Sola1']
# [Container Node] li Sola2
# <li>Sola2
# </li>
# Sola2
#
# ['Transposable Element', 'DNA transposon', 'Sola', 'Sola2']
# [Container Node] li Sola3
# <li>Sola3
# </li>
# Sola3
#
# ['Transposable Element', 'DNA transposon', 'Sola', 'Sola3']
#
#
# ['Transposable Element', 'DNA transposon', 'Sola']
# [Container Node] li Zator
# <li>Zator
# </li>
# Zator
#
# ['Transposable Element', 'DNA transposon', 'Zator']
# [Container Node] li Ginger1
# <li>Ginger1
# </li>
# Ginger1
#
# ['Transposable Element', 'DNA transposon', 'Ginger1']
# [Container Node] li Ginger2/TDD
# <li>Ginger2/TDD
# </li>
# Ginger2/TDD
#
# ['Transposable Element', 'DNA transposon', 'Ginger2/TDD']
# [Container Node] li Academ
# <li>Academ
# </li>
# Academ
#
# ['Transposable Element', 'DNA transposon', 'Academ']
# [Container Node] li Zisupton
# <li>Zisupton
# </li>
# Zisupton
#
# ['Transposable Element', 'DNA transposon', 'Zisupton']
# [Container Node] li IS3EU
# <li>IS3EU
# </li>
# IS3EU
#
# ['Transposable Element', 'DNA transposon', 'IS3EU']
# [Container Node] li Dada
# <li>Dada
# </li>
# Dada
#
# ['Transposable Element', 'DNA transposon', 'Dada']
#
#
# ['Transposable Element', 'DNA transposon']
# [Container Node] li LTR Retrotransposon
# <li>LTR Retrotransposon
# <ul>
# <li>Gypsy
# </li><li>Copia
# </li><li>BEL
# </li><li>DIRS
# </li></ul>
# </li>
# LTR Retrotransposon
#
# ['Transposable Element', 'LTR Retrotransposon']
# [Container Node] ul
# <ul>
# <li>Gypsy
# </li><li>Copia
# </li><li>BEL
# </li><li>DIRS
# </li></ul>
#
#
# ['Transposable Element', 'LTR Retrotransposon']
# [Container Node] li Gypsy
# <li>Gypsy
# </li>
# Gypsy
#
# ['Transposable Element', 'LTR Retrotransposon', 'Gypsy']
# [Container Node] li Copia
# <li>Copia
# </li>
# Copia
#
# ['Transposable Element', 'LTR Retrotransposon', 'Copia']
# [Container Node] li BEL
# <li>BEL
# </li>
# BEL
#
# ['Transposable Element', 'LTR Retrotransposon', 'BEL']
# [Container Node] li DIRS
# <li>DIRS
# </li>
# DIRS
#
# ['Transposable Element', 'LTR Retrotransposon', 'DIRS']
#
#
# ['Transposable Element', 'LTR Retrotransposon']
# [Container Node] li Endogenous Retrovirus
# <li>Endogenous Retrovirus
# <ul>
# <li>ERV1
# </li><li>ERV2
# </li><li>ERV3
# </li><li>Lentivirus
# </li><li>ERV4
# </li></ul>
# </li>
# Endogenous Retrovirus
#
# ['Transposable Element', 'Endogenous Retrovirus']
# [Container Node] ul
# <ul>
# <li>ERV1
# </li><li>ERV2
# </li><li>ERV3
# </li><li>Lentivirus
# </li><li>ERV4
# </li></ul>
#
#
# ['Transposable Element', 'Endogenous Retrovirus']
# [Container Node] li ERV1
# <li>ERV1
# </li>
# ERV1
#
# ['Transposable Element', 'Endogenous Retrovirus', 'ERV1']
# [Container Node] li ERV2
# <li>ERV2
# </li>
# ERV2
#
# ['Transposable Element', 'Endogenous Retrovirus', 'ERV2']
# [Container Node] li ERV3
# <li>ERV3
# </li>
# ERV3
#
# ['Transposable Element', 'Endogenous Retrovirus', 'ERV3']
# [Container Node] li Lentivirus
# <li>Lentivirus
# </li>
# Lentivirus
#
# ['Transposable Element', 'Endogenous Retrovirus', 'Lentivirus']
# [Container Node] li ERV4
# <li>ERV4
# </li>
# ERV4
#
# ['Transposable Element', 'Endogenous Retrovirus', 'ERV4']
#
#
# ['Transposable Element', 'Endogenous Retrovirus']
# [Container Node] li Non-LTR Retrotransposon
# <li>Non-LTR Retrotransposon
# <ul>
# <li>SINE
# <ul>
# <li>SINE1/7SL
# </li><li>SINE2/tRNA
# </li><li>SINE3/5S
# </li><li>SINE4
# </li><li>SINEU/snRNA
# </li></ul>
# </li><li>CRE
# </li><li>NeSL
# </li><li>R4
# </li><li>R2
# </li><li>L1
# </li><li>RTE
# </li><li>I
# </li><li>Jockey
# </li><li>CR1
# </li><li>Rex1
# </li><li>RandI
# </li><li>Penelope
# </li><li>Tx1
# </li><li>RTEX
# </li><li>Crack
# </li><li>Nimb
# </li><li>Proto1
# </li><li>Proto2
# </li><li>RTETP
# </li><li>Hero
# </li><li>L2
# </li><li>Tad1
# </li><li>Loa
# </li><li>Ingi
# </li><li>Outcast
# </li><li>R1
# </li><li>Daphne
# </li><li>L2A
# </li><li>L2B
# </li><li>Ambal
# </li><li>Vingi
# </li><li>Kiri
# </li></ul>
# </li>
# Non-LTR Retrotransposon
#
# ['Transposable Element', 'Non-LTR Retrotransposon']
# [Container Node] ul
# <ul>
# <li>SINE
# <ul>
# <li>SINE1/7SL
# </li><li>SINE2/tRNA
# </li><li>SINE3/5S
# </li><li>SINE4
# </li><li>SINEU/snRNA
# </li></ul>
# </li><li>CRE
# </li><li>NeSL
# </li><li>R4
# </li><li>R2
# </li><li>L1
# </li><li>RTE
# </li><li>I
# </li><li>Jockey
# </li><li>CR1
# </li><li>Rex1
# </li><li>RandI
# </li><li>Penelope
# </li><li>Tx1
# </li><li>RTEX
# </li><li>Crack
# </li><li>Nimb
# </li><li>Proto1
# </li><li>Proto2
# </li><li>RTETP
# </li><li>Hero
# </li><li>L2
# </li><li>Tad1
# </li><li>Loa
# </li><li>Ingi
# </li><li>Outcast
# </li><li>R1
# </li><li>Daphne
# </li><li>L2A
# </li><li>L2B
# </li><li>Ambal
# </li><li>Vingi
# </li><li>Kiri
# </li></ul>
#
#
# ['Transposable Element', 'Non-LTR Retrotransposon']
# [Container Node] li SINE
# <li>SINE
# <ul>
# <li>SINE1/7SL
# </li><li>SINE2/tRNA
# </li><li>SINE3/5S
# </li><li>SINE4
# </li><li>SINEU/snRNA
# </li></ul>
# </li>
# SINE
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'SINE']
# [Container Node] ul
# <ul>
# <li>SINE1/7SL
# </li><li>SINE2/tRNA
# </li><li>SINE3/5S
# </li><li>SINE4
# </li><li>SINEU/snRNA
# </li></ul>
#
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'SINE']
# [Container Node] li SINE1/7SL
# <li>SINE1/7SL
# </li>
# SINE1/7SL
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'SINE', 'SINE1/7SL']
# [Container Node] li SINE2/tRNA
# <li>SINE2/tRNA
# </li>
# SINE2/tRNA
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'SINE', 'SINE2/tRNA']
# [Container Node] li SINE3/5S
# <li>SINE3/5S
# </li>
# SINE3/5S
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'SINE', 'SINE3/5S']
# [Container Node] li SINE4
# <li>SINE4
# </li>
# SINE4
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'SINE', 'SINE4']
# [Container Node] li SINEU/snRNA
# <li>SINEU/snRNA
# </li>
# SINEU/snRNA
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'SINE', 'SINEU/snRNA']
#
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'SINE']
# [Container Node] li CRE
# <li>CRE
# </li>
# CRE
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'CRE']
# [Container Node] li NeSL
# <li>NeSL
# </li>
# NeSL
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'NeSL']
# [Container Node] li R4
# <li>R4
# </li>
# R4
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'R4']
# [Container Node] li R2
# <li>R2
# </li>
# R2
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'R2']
# [Container Node] li L1
# <li>L1
# </li>
# L1
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'L1']
# [Container Node] li RTE
# <li>RTE
# </li>
# RTE
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'RTE']
# [Container Node] li I
# <li>I
# </li>
# I
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'I']
# [Container Node] li Jockey
# <li>Jockey
# </li>
# Jockey
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Jockey']
# [Container Node] li CR1
# <li>CR1
# </li>
# CR1
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'CR1']
# [Container Node] li Rex1
# <li>Rex1
# </li>
# Rex1
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Rex1']
# [Container Node] li RandI
# <li>RandI
# </li>
# RandI
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'RandI']
# [Container Node] li Penelope
# <li>Penelope
# </li>
# Penelope
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Penelope']
# [Container Node] li Tx1
# <li>Tx1
# </li>
# Tx1
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Tx1']
# [Container Node] li RTEX
# <li>RTEX
# </li>
# RTEX
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'RTEX']
# [Container Node] li Crack
# <li>Crack
# </li>
# Crack
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Crack']
# [Container Node] li Nimb
# <li>Nimb
# </li>
# Nimb
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Nimb']
# [Container Node] li Proto1
# <li>Proto1
# </li>
# Proto1
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Proto1']
# [Container Node] li Proto2
# <li>Proto2
# </li>
# Proto2
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Proto2']
# [Container Node] li RTETP
# <li>RTETP
# </li>
# RTETP
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'RTETP']
# [Container Node] li Hero
# <li>Hero
# </li>
# Hero
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Hero']
# [Container Node] li L2
# <li>L2
# </li>
# L2
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'L2']
# [Container Node] li Tad1
# <li>Tad1
# </li>
# Tad1
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Tad1']
# [Container Node] li Loa
# <li>Loa
# </li>
# Loa
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Loa']
# [Container Node] li Ingi
# <li>Ingi
# </li>
# Ingi
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Ingi']
# [Container Node] li Outcast
# <li>Outcast
# </li>
# Outcast
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Outcast']
# [Container Node] li R1
# <li>R1
# </li>
# R1
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'R1']
# [Container Node] li Daphne
# <li>Daphne
# </li>
# Daphne
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Daphne']
# [Container Node] li L2A
# <li>L2A
# </li>
# L2A
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'L2A']
# [Container Node] li L2B
# <li>L2B
# </li>
# L2B
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'L2B']
# [Container Node] li Ambal
# <li>Ambal
# </li>
# Ambal
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Ambal']
# [Container Node] li Vingi
# <li>Vingi
# </li>
# Vingi
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Vingi']
# [Container Node] li Kiri
# <li>Kiri
# </li>
# Kiri
#
# ['Transposable Element', 'Non-LTR Retrotransposon', 'Kiri']
#
#
# ['Transposable Element', 'Non-LTR Retrotransposon']
#
#
# ['Transposable Element']
# [Container Node] li Simple Repeat
# <li>Simple Repeat
# <ul>
# <li>Satellite
# <ul>
# <li>SAT
# </li><li>MSAT
# </li></ul>
# </li></ul>
# </li>
# Simple Repeat
#
# ['Simple Repeat']
# [Container Node] ul
# <ul>
# <li>Satellite
# <ul>
# <li>SAT
# </li><li>MSAT
# </li></ul>
# </li></ul>
#
#
# ['Simple Repeat']
# [Container Node] li Satellite
# <li>Satellite
# <ul>
# <li>SAT
# </li><li>MSAT
# </li></ul>
# </li>
# Satellite
#
# ['Simple Repeat', 'Satellite']
# [Container Node] ul
# <ul>
# <li>SAT
# </li><li>MSAT
# </li></ul>
#
#
# ['Simple Repeat', 'Satellite']
# [Container Node] li SAT
# <li>SAT
# </li>
# SAT
#
# ['Simple Repeat', 'Satellite', 'SAT']
# [Container Node] li MSAT
# <li>MSAT
# </li>
# MSAT
#
# ['Simple Repeat', 'Satellite', 'MSAT']
#
#
# ['Simple Repeat', 'Satellite']
#
#
# ['Simple Repeat']
# [Container Node] li Multicopy gene
# <li>Multicopy gene
# <ul>
# <li>rRNA
# </li><li>tRNA
# </li><li>snRNA
# </li></ul>
# </li>
# Multicopy gene
#
# ['Multicopy gene']
# [Container Node] ul
# <ul>
# <li>rRNA
# </li><li>tRNA
# </li><li>snRNA
# </li></ul>
#
#
# ['Multicopy gene']
# [Container Node] li rRNA
# <li>rRNA
# </li>
# rRNA
#
# ['Multicopy gene', 'rRNA']
# [Container Node] li tRNA
# <li>tRNA
# </li>
# tRNA
#
# ['Multicopy gene', 'tRNA']
# [Container Node] li snRNA
# <li>snRNA
# </li>
# snRNA
#
# ['Multicopy gene', 'snRNA']
#
#
# ['Multicopy gene']
# [Container Node] li Integrated Virus
# <li>Integrated Virus
# <ul>
# <li>DNA Virus
# </li><li>Caulimoviridae
# </li></ul>
# </li>
# Integrated Virus
#
# ['Integrated Virus']
# [Container Node] ul
# <ul>
# <li>DNA Virus
# </li><li>Caulimoviridae
# </li></ul>
#
#
# ['Integrated Virus']
# [Container Node] li DNA Virus
# <li>DNA Virus
# </li>
# DNA Virus
#
# ['Integrated Virus', 'DNA Virus']
# [Container Node] li Caulimoviridae
# <li>Caulimoviridae
# </li>
# Caulimoviridae
#
# ['Integrated Virus', 'Caulimoviridae']
#
#
# ['Integrated Virus']

# %%
for child in soup.ul.small.li.ul.childGenerator():
    name = getattr(child, "name", None)
    print(name)
# Out:
# None
# li
# li
# li
# li
